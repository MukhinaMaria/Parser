# %% [markdown]
# <a href="https://colab.research.google.com/github/MukhinaMaria/Parser/blob/main/Parser_%D0%9C%D1%83%D1%85%D0%B8%D0%BD%D0%B0_%D0%9C_%D0%94_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyquery

# %%
import requests
from pyquery import PyQuery as pq

doc = pq(url="https://meteoinfo.ru/mosobl")
#tag = pq.PyQuery('div#id') # or     tag = pq('div.class')
row = 0
col = 0
data = []
for link in doc('tr>td'):
   print(link.text)
# Out:
#
# None
# Температура воздуха, °C
# Осадки
# Станция
# T
# None
# None
# T
# Осадки днем, мм
# Осадки ночью, мм
# BHУKOBO
#  -2.7
#  -6.9 (20)
#  -7.1 (21)
# -11.7
#  ---
#  ---
# ДOMOДEДOBO
#  -4.4
#  -7.2 (20)
#  -7.2 (21)
# -12.9
#  ---
#  ---
# ШEPEMETЬEBO
#  -2.2
#  -6.5 (18)
#  -6.8 (21)
# -11.2
#  ---
#  ---
# EГOPЬEBCK
#  -4.3
#  -7.5 (18)
#  -9.5 (21)
# -13.7
# - - -
# - - -
# ВОЛОКОЛАМСК
#  -3.3
#  -6.6 (18)
#  -8.1 (21)
# -11.4
#  ---
#  0.0
# MOЖAЙCK
#  -2.4
#  -6.2 (18)
#  -7.6 (21)
# -11.8
#  ---
#  ---
# H.-ИЕРУСАЛИМ
#  -2.8
#  -7.4 (18)
#  -9.0 (21)
# -12.7
#  ---
#  ---
# HEMЧИHOBKA
#  -2.6
#  -6.7 (18)
#  -6.9 (21)
# -10.9
#  ---
#  ---
# ПOДMOCKOBHAЯ
#  -3.2
#  -7.4 (18)
#  -6.8 (21)
# -12.9
#  ---
#  ---
# ПАВ.ПОСАД
#  -3.7
#  -7.3 (18)
#  -7.5 (21)
# -13.3
#  ---
#  0.0
# БАЛЧУГ
#  -3.3
#  -5.6 (18)
#  -6.2 (21)
#  -5.8
#  ---
#  ---
# HАРО-ФОМИHСК
#  -3.2
#  -7.2 (18)
#  -7.5 (21)
# -12.5
#  ---
#  ---
# MИXAЙЛOBCKOE
#  -3.6
#  -7.1 (18)
#  -7.5 (21)
# -13.4
# ...

# %% [markdown]
# ![Модель данных_парсинг.jpg](data:image/jpeg;base64,...)
